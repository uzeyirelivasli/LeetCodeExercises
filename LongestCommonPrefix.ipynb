# %%
# I DIDN'T WRITE THIS ONE. IT'S HERE FOR ME TO LEARN 
#  * , ZIP() , SET() , ENUMERATE()

class Solution:
    def longestCommonPrefix(self, strs):
        if not strs: return ""
        
        # Kelimeleri karakter karakter eşleştir: ('f','f','f'), ('l','l','l'), ('o','o','i')...
        for i, chars in enumerate(zip(*strs)):
            # Eğer tüm karakterler aynı değilse (set uzunluğu 1'den büyükse)
            if len(set(chars)) > 1:
                return strs[0][:i]
        
        # Tüm karakterler eşleştiyse en kısa kelime prefix'tir
        return min(strs, key=len)
